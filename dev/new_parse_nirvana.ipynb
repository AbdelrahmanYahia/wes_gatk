# %%
import pandas as pd
import json
import gzip
import os

file = "/home/marc/inters/output_test2/05_Annotation/Nirvana/snvs/Annotation.json.gz"
gene_info = "/home/marc/Desktop/data/refs/gtf/GRCH38_91/gene.info"
Jasix = os.path.expanduser("$HOME/Nirvana/bin/Release/net6.0/Jasix.dll")

# %%
id = "FAM138A"
padding = 1000

# %%
def extract_gene_region(Ann_file, gene_info, id, padding=1000):
    interval = os.popen(f"grep -i 'Name={id};' {gene_info} | awk -F'\t' '{{print \"chr\"$1\":\"$4-{padding}\"-\"$5+{padding}}}'").read().strip()
    if interval == '':
        print("didn't find Gene in Gene list!")
        return None
    else:
        print(F"Exporting {id} with padding [ {padding} ] ({interval})  from Annotation file...")
        dotnet_command = f"dotnet {Jasix} -i {file} -q {interval}"
        dotnet_output = os.popen(dotnet_command)
        dotnet_output_str = dotnet_output.read().replace("\n","")
        dotnet_output_exitcode = dotnet_output.close()
        if dotnet_output_exitcode is not None:
            print(f"ERROR with dotnet command! maybe didn't find the gene {id}")
            return None
        else:
            formatted_output = dotnet_output_str.replace("{  \"chromosome", "\n{\"chromosome")
            formatted_output = formatted_output.replace(" ", "")
            formatted_output = formatted_output.replace('{"positions":[\n{', '[{').replace("}]}]}]}","}]}]}]")

            return pd.DataFrame(json.loads(formatted_output))

def process_region(*args):
    counter = 0
    for df in args:
        if counter == 0:
            my_df = df
        else:
            my_df = pd.concat([my_df, df], axis=0, ignore_index=True)
        counter += 1
        
    return my_df

def process_dataframe(df):
    df = pd.DataFrame(df)
    try:
        variants_df = df['variants'].apply(pd.Series)
        variants_df2 = variants_df[0].apply(pd.Series)
        final_df = pd.concat([df, variants_df2], axis=1).drop(['variants', 'samples'], axis=1)
        return final_df

    except:
        print("No match found for any of the provided genes!")



def print_stats(final_df):
    try:
        total_rows = len(final_df)
        total_variants = total_rows
        variants_with_annotations = total_rows - final_df['dbsnp'].isna().sum()
        variants_with_regulatoryRegions = total_rows - final_df['regulatoryRegions'].isna().sum()
        variants_with_inlowcomplexity = total_rows - final_df['inLowComplexityRegion'].isna().sum()
        novel_variants = total_variants - variants_with_annotations
        percentage_novel = round(((novel_variants / total_rows) * 100),2)
        print(f"Total Variants: {total_variants}")
        print(f"No. Variants with dbSNP Annotations: {variants_with_annotations}")
        print(f"No. Variants affecting regualtory regions: {variants_with_regulatoryRegions}")
        print(f"No. Variants in low complexity regions: {variants_with_inlowcomplexity}")
        print(f"Percentage of Unknown Variants (dbsnp only): {percentage_novel} %")
    except:
        exit(1)

# %%
egene = extract_gene_region(file, gene_info, "OR4F21", 5000)
egene2 = extract_gene_region(file, gene_info, "FBXO16", 5000)
egene3 = extract_gene_region(file, gene_info, "FGL1", 5000)
egene4 = extract_gene_region(file, gene_info, "c", 5000)
# Out:
# Exporting OR4F21 with padding [ 5000 ] (chr8:161049-172043)  from Annotation file...
# Exporting FBXO16 with padding [ 5000 ] (chr8:28343287-28495318)  from Annotation file...
# Exporting FGL1 with padding [ 5000 ] (chr8:17859380-17915365)  from Annotation file...
# Exporting FAM138A with padding [ 5000 ] (chr1:29554-41081)  from Annotation file...
# ERROR with dotnet command! maybe didn't find the gene FAM138A

# %%
combined = process_region(egene4)
final_df = print_stats(process_dataframe(combined))
# Out:
# No match found for any of the provided genes!

# %%
combined = process_region(egene,egene2,egene3,egene4)
final_df = print_stats(process_dataframe(combined))
# Out:
# Total Variants: 54
# No. Variants with dbSNP Annotations: 5
# No. Variants affecting regualtory regions: 5
# No. Variants in low complexity regions: 3
# Percentage of Unknown Variants (dbsnp only): 90.74 %

# %%
final_df
# Out:
#    chromosome  position refAllele altAlleles   quality       filters  \
# 0        chr8    161062         C        [T]   3448.97        [PASS]
# 1        chr8    161167         C        [T]    585.97        [PASS]
# 2        chr8    161176         T        [C]    598.97        [PASS]
# 3        chr8    161240         A        [G]    218.29        [PASS]
# 4        chr8    163226         T        [C]   8887.16        [PASS]
# 5        chr8    163249         T        [C]   8929.16        [PASS]
# 6        chr8    163366         T        [C]  16714.98        [PASS]
# 7        chr8    163370         C        [G]  43882.73        [PASS]
# 8        chr8    163387         C        [T]  11856.16        [PASS]
# 9        chr8    163432         A        [G]  12922.98        [PASS]
# 10       chr8    163438         C        [T]  29208.73        [PASS]
# 11       chr8    163550         A        [G]  16612.73        [PASS]
# 12       chr8    163553         T        [C]   8151.98        [PASS]
# 13       chr8    163654         C        [T]   7071.98        [PASS]
# 14       chr8    163784         C        [G]   4390.73        [SOR3]
# 15       chr8    169283         T        [G]    789.63  [FS60, SOR3]
# 16       chr8    169305         G        [C]     46.29   [QD2, SOR3]
# 17       chr8    169366         T        [C]  11982.73        [PASS]
# 18       chr8    169403         G        [A]    320.29        [PASS]
# 19       chr8    169422         G        [C]    134.29         [QD2]
# 20       chr8    169428         A        [C]    141.63         [QD2]
# 21       chr8    169476         C        [G]    856.16        [PASS]
# 22       chr8    169483         T     [C, G]    904.72        [PASS]
# 23       chr8    169489         T        [C]    129.90         [QD2]
# 24       chr8    169641         A        [G]     86.29        [PASS]
# 25       chr8  28347508         A        [G]    609.71        [SOR3]
# 26       chr8  28357666         C        [T]    787.16        [PASS]
# 27       chr8  28384712         A        [G]   4721.73        [PASS]
# 28       chr8  28421076         G        [A]   8986.73        [PASS]
# 29       chr8  28421781         A        [C]   2780.73        [SOR3]
# 30       chr8  17867185         A        [T]   1914.16        [PASS]
# 31       chr8  17868029         C        [A]   1037.16        [PASS]
# 32       chr8  17868088         T        [G]   1563.16        [PASS]
# 33       chr8  17868219         C        [T]    760.16        [PASS]
# 34       chr8  17868245         C        [A]   1210.98        [SOR3]
# 35       chr8  17868521         T        [C]    201.29        [PASS]
# 36       chr8  17871598         T        [A]    896.16        [PASS]
# 37       chr8  17882712         C        [G]   1210.16        [PASS]
# 38       chr8  17882814         C        [T]   1491.16        [PASS]
# 39       chr8  17883296         G        [A]   1195.98        [PASS]
# 40       chr8  17885119         A        [G]    603.19        [PASS]
# 41       chr8  17885384         T        [C]   3029.16        [PASS]
# 42       chr8  17885406         C        [G]   7011.98        [PASS]
# 43       chr8  17885862         A        [G]   1408.16        [PASS]
# 44       chr8  17885907         A        [C]   1753.16        [PASS]
# 45       chr8  17886026         G        [A]   9862.98        [PASS]
# 46       chr8  17886345         T        [C]    783.16        [PASS]
# 47       chr8  17887062         T        [C]   4371.16        [PASS]
# 48       chr8  17887414         G        [A]    527.16        [PASS]
# 49       chr8  17913753         T        [C]    328.29        [PASS]
# 50       chr8  17913813         G        [A]   1962.16        [PASS]
# 51       chr8  17913970         G        [A]   2734.16        [PASS]
# 52       chr8  17914919         A        [T]   1110.16        [PASS]
# 53       chr8  17915299         T        [C]    293.90        [PASS]
#
#     fisherStrandBias  mappingQuality cytogeneticBand             vid  ...  \
# 0             12.287           60.00          8p23.3    8-161062-C-T  ...
# 1              0.000           60.00          8p23.3    8-161167-C-T  ...
# 2              0.000           60.00          8p23.3    8-161176-T-C  ...
# 3              0.000           60.00          8p23.3    8-161240-A-G  ...
# 4              5.194           60.00          8p23.3    8-163226-T-C  ...
# 5              9.989           60.00          8p23.3    8-163249-T-C  ...
# 6              0.000           59.98          8p23.3    8-163366-T-C  ...
# 7              0.000           59.98          8p23.3    8-163370-C-G  ...
# 8              9.653           59.99          8p23.3    8-163387-C-T  ...
# 9             22.033           59.96          8p23.3    8-163432-A-G  ...
# 10             0.000           59.96          8p23.3    8-163438-C-T  ...
# 11             0.000           60.00          8p23.3    8-163550-A-G  ...
# 12            32.279           60.00          8p23.3    8-163553-T-C  ...
# 13            13.321           60.00          8p23.3    8-163654-C-T  ...
# 14             0.000           60.00          8p23.3    8-163784-C-G  ...
# 15            79.982           51.89          8p23.3    8-169283-T-G  ...
# 16            42.166           51.61          8p23.3    8-169305-G-C  ...
# 17             7.761           58.19          8p23.3    8-169366-T-C  ...
# 18             6.549           59.29          8p23.3    8-169403-G-A  ...
# 19             6.976           59.25          8p23.3    8-169422-G-C  ...
# 20             4.555           59.25          8p23.3    8-169428-A-C  ...
# 21             0.000           59.60          8p23.3    8-169476-C-G  ...
# 22             0.000           59.49          8p23.3    8-169483-T-C  ...
# 23             0.000           59.46          8p23.3    8-169489-T-C  ...
# 24             0.000           58.10          8p23.3    8-169641-A-G  ...
# 25             0.000           60.00          8p21.1  8-28347508-A-G  ...
# 26             0.000           60.00          8p21.1  8-28357666-C-T  ...
# 27             0.000           60.00          8p21.1  8-28384712-A-G  ...
# 28             0.000           60.00          8p21.1  8-28421076-G-A  ...
# 29             0.000           60.00          8p21.1  8-28421781-A-C  ...
# 30             6.537           60.00            8p22  8-17867185-A-T  ...
# 31             0.000           60.00            8p22  8-17868029-C-A  ...
# 32             1.508           60.00            8p22  8-17868088-T-G  ...
# 33             0.000           60.00            8p22  8-17868219-C-T  ...
# 34             5.006           60.00            8p22  8-17868245-C-A  ...
# 35             0.000           60.00            8p22  8-17868521-T-C  ...
# 36             4.953           60.00            8p22  8-17871598-T-A  ...
# 37             0.000           60.00            8p22  8-17882712-C-G  ...
# 38             1.453           60.00            8p22  8-17882814-C-T  ...
# 39             0.000           60.00            8p22  8-17883296-G-A  ...
# 40             0.000           60.00            8p22  8-17885119-A-G  ...
# 41             3.275           59.84            8p22  8-17885384-T-C  ...
# 42             5.994           60.00            8p22  8-17885406-C-G  ...
# 43             0.000           60.00            8p22  8-17885862-A-G  ...
# 44             5.432           60.00            8p22  8-17885907-A-C  ...
# 45             6.240           60.00            8p22  8-17886026-G-A  ...
# 46             0.000           60.00            8p22  8-17886345-T-C  ...
# 47             5.681           60.00            8p22  8-17887062-T-C  ...
# 48             0.000           60.00            8p22  8-17887414-G-A  ...
# 49             0.000           60.00            8p22  8-17913753-T-C  ...
# 50             0.000           60.00            8p22  8-17913813-G-A  ...
# 51             1.215           60.00            8p22  8-17913970-G-A  ...
# 52            11.981           60.00            8p22  8-17914919-A-T  ...
# 53             0.000           60.00            8p22  8-17915299-T-C  ...
#
#                          hgvsg  phylopScore  dannScore  \
# 0     NC_000008.11:g.161062C>T          0.2       0.36
# 1     NC_000008.11:g.161167C>T         -1.2       0.64
# 2     NC_000008.11:g.161176T>C          0.2       0.33
# 3     NC_000008.11:g.161240A>G          0.2        NaN
# 4     NC_000008.11:g.163226T>C          0.2        NaN
# 5     NC_000008.11:g.163249T>C          0.2       0.44
# 6     NC_000008.11:g.163366T>C          0.2       0.47
# 7     NC_000008.11:g.163370C>G          0.2       0.39
# 8     NC_000008.11:g.163387C>T          0.2        NaN
# 9     NC_000008.11:g.163432A>G          0.2       0.67
# 10    NC_000008.11:g.163438C>T         -1.1       0.82
# 11    NC_000008.11:g.163550A>G         -0.3       0.31
# 12    NC_000008.11:g.163553T>C          0.6       0.43
# 13    NC_000008.11:g.163654C>T         -1.2        NaN
# 14    NC_000008.11:g.163784C>G          0.6       0.96
# 15    NC_000008.11:g.169283T>G          0.5       0.52
# 16    NC_000008.11:g.169305G>C         -0.8        NaN
# 17    NC_000008.11:g.169366T>C          0.4       0.88
# 18    NC_000008.11:g.169403G>A          0.5        NaN
# 19    NC_000008.11:g.169422G>C          0.4        NaN
# 20    NC_000008.11:g.169428A>C          0.5       0.70
# 21    NC_000008.11:g.169476C>G          0.5       0.88
# 22    NC_000008.11:g.169483T>C         -0.7       0.53
# 23    NC_000008.11:g.169489T>C          0.4       0.76
# 24    NC_000008.11:g.169641A>G          0.4       0.91
# 25  NC_000008.11:g.28347508A>G         -0.6        NaN
# 26  NC_000008.11:g.28357666C>T          0.1        NaN
# 27  NC_000008.11:g.28384712A>G         -0.5       0.74
# 28  NC_000008.11:g.28421076G>A         -0.8       0.48
# 29  NC_000008.11:g.28421781A>C          0.0       0.71
# 30  NC_000008.11:g.17867185A>T          0.7       0.44
# 31  NC_000008.11:g.17868029C>A          0.7       0.74
# 32  NC_000008.11:g.17868088T>G         -0.1        NaN
# 33  NC_000008.11:g.17868219C>T         -0.4       0.82
# 34  NC_000008.11:g.17868245C>A          1.0        NaN
# 35  NC_000008.11:g.17868521T>C          0.0       0.48
# 36  NC_000008.11:g.17871598T>A          0.0        NaN
# 37  NC_000008.11:g.17882712C>G          0.1       0.10
# 38  NC_000008.11:g.17882814C>T         -1.4       0.06
# 39  NC_000008.11:g.17883296G>A          NaN       0.05
# 40  NC_000008.11:g.17885119A>G          0.2       0.66
# 41  NC_000008.11:g.17885384T>C         -0.6       0.42
# 42  NC_000008.11:g.17885406C>G          0.1       0.66
# 43  NC_000008.11:g.17885862A>G          0.4       0.81
# 44  NC_000008.11:g.17885907A>C          0.4       0.31
# 45  NC_000008.11:g.17886026G>A          0.4       0.69
# 46  NC_000008.11:g.17886345T>C          0.8       0.68
# 47  NC_000008.11:g.17887062T>C         -0.2       0.75
# 48  NC_000008.11:g.17887414G>A          0.7        NaN
# 49  NC_000008.11:g.17913753T>C         -0.7       0.34
# 50  NC_000008.11:g.17913813G>A          0.3       0.53
# 51  NC_000008.11:g.17913970G>A          0.3       0.42
# 52  NC_000008.11:g.17914919A>T          0.3        NaN
# 53  NC_000008.11:g.17915299T>C          0.3       0.75
#
#                                           transcripts           dbsnp  \
# 0   [{'transcript': 'ENST00000320901.3', 'source':...             NaN
# 1   [{'transcript': 'ENST00000320901.3', 'source':...   [rs200059412]
# 2   [{'transcript': 'ENST00000320901.3', 'source':...  [rs1241218637]
# 3   [{'transcript': 'ENST00000320901.3', 'source':...             NaN
# 4   [{'transcript': 'ENST00000320901.3', 'source':...             NaN
# 5   [{'transcript': 'ENST00000320901.3', 'source':...             NaN
# 6   [{'transcript': 'ENST00000320901.3', 'source':...  [rs1376642346]
# 7   [{'transcript': 'ENST00000320901.3', 'source':...             NaN
# 8   [{'transcript': 'ENST00000320901.3', 'source':...             NaN
# 9   [{'transcript': 'ENST00000320901.3', 'source':...             NaN
# 10  [{'transcript': 'ENST00000320901.3', 'source':...  [rs1182427664]
# 11  [{'transcript': 'ENST00000320901.3', 'source':...             NaN
# 12  [{'transcript': 'ENST00000320901.3', 'source':...             NaN
# 13  [{'transcript': 'ENST00000320901.3', 'source':...             NaN
# 14  [{'transcript': 'ENST00000320901.3', 'source':...             NaN
# 15  [{'transcript': 'ENST00000320901.3', 'source':...             NaN
# 16  [{'transcript': 'ENST00000320901.3', 'source':...             NaN
# 17  [{'transcript': 'ENST00000320901.3', 'source':...             NaN
# 18  [{'transcript': 'ENST00000320901.3', 'source':...             NaN
# 19  [{'transcript': 'ENST00000320901.3', 'source':...             NaN
# 20  [{'transcript': 'ENST00000320901.3', 'source':...             NaN
# 21  [{'transcript': 'ENST00000320901.3', 'source':...             NaN
# 22  [{'transcript': 'ENST00000320901.3', 'source':...             NaN
# 23  [{'transcript': 'ENST00000320901.3', 'source':...             NaN
# 24  [{'transcript': 'ENST00000320901.3', 'source':...             NaN
# 25  [{'transcript': 'ENST00000301908.7', 'source':...             NaN
# 26  [{'transcript': 'NM_018660.2', 'source': 'RefS...             NaN
# 27  [{'transcript': 'NM_018660.2', 'source': 'RefS...             NaN
# 28  [{'transcript': 'ENST00000521548.5', 'source':...             NaN
# 29  [{'transcript': 'ENST00000521548.5', 'source':...             NaN
# 30  [{'transcript': 'ENST00000398056.6', 'source':...             NaN
# 31  [{'transcript': 'ENST00000398056.6', 'source':...             NaN
# 32  [{'transcript': 'ENST00000398056.6', 'source':...             NaN
# 33  [{'transcript': 'ENST00000398056.6', 'source':...             NaN
# 34  [{'transcript': 'ENST00000398056.6', 'source':...             NaN
# 35  [{'transcript': 'ENST00000398056.6', 'source':...             NaN
# 36  [{'transcript': 'ENST00000398056.6', 'source':...             NaN
# 37  [{'transcript': 'ENST00000398056.6', 'source':...             NaN
# 38  [{'transcript': 'ENST00000398056.6', 'source':...             NaN
# 39  [{'transcript': 'ENST00000398056.6', 'source':...             NaN
# 40  [{'transcript': 'ENST00000398056.6', 'source':...             NaN
# 41  [{'transcript': 'ENST00000398056.6', 'source':...             NaN
# 42  [{'transcript': 'ENST00000398056.6', 'source':...             NaN
# 43  [{'transcript': 'ENST00000398056.6', 'source':...             NaN
# 44  [{'transcript': 'ENST00000398056.6', 'source':...             NaN
# 45  [{'transcript': 'ENST00000398056.6', 'source':...             NaN
# 46  [{'transcript': 'ENST00000398056.6', 'source':...             NaN
# 47  [{'transcript': 'ENST00000398056.6', 'source':...             NaN
# 48  [{'transcript': 'ENST00000398056.6', 'source':...             NaN
# 49  [{'transcript': 'ENST00000398056.6', 'source':...             NaN
# 50  [{'transcript': 'ENST00000398056.6', 'source':...             NaN
# 51  [{'transcript': 'ENST00000398056.6', 'source':...             NaN
# 52  [{'transcript': 'ENST00000398056.6', 'source':...             NaN
# 53  [{'transcript': 'ENST00000398056.6', 'source':...  [rs2053923352]
#
#                                                gnomad  \
# 0                                                 NaN
# 1                                                 NaN
# 2   {'coverage': 0, 'failedFilter': True, 'allAf':...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   {'coverage': 0, 'allAf': 1.4e-05, 'allAn': 148...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  {'coverage': 0, 'allAf': 0.000129, 'allAn': 13...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
#
#                                                topmed  gerpScore  \
# 0                                                 NaN        NaN
# 1                                                 NaN        NaN
# 2   {'allAf': 8e-06, 'allAn': 125568, 'allAc': 1, ...        NaN
# 3                                                 NaN    -0.7420
# 4                                                 NaN        NaN
# 5                                                 NaN        NaN
# 6   {'allAf': 1.6e-05, 'allAn': 125568, 'allAc': 2...     1.2900
# 7                                                 NaN     2.7400
# 8                                                 NaN        NaN
# 9                                                 NaN     1.9900
# 10  {'allAf': 0.000111, 'allAn': 125568, 'allAc': ...    -1.5100
# 11                                                NaN    -1.8000
# 12                                                NaN    -0.9790
# 13                                                NaN        NaN
# 14                                                NaN     1.0800
# 15                                                NaN    -4.9100
# 16                                                NaN     0.2780
# 17                                                NaN    -2.8400
# 18                                                NaN     1.3600
# 19                                                NaN    -0.9010
# 20                                                NaN     0.1440
# 21                                                NaN     1.4600
# 22                                                NaN    -1.1400
# 23                                                NaN     0.4260
# 24                                                NaN    -1.6000
# 25                                                NaN    -3.8700
# 26                                                NaN     1.1800
# 27                                                NaN    -3.4400
# 28                                                NaN    -0.5520
# 29                                                NaN    -0.7230
# 30                                                NaN     0.8240
# 31                                                NaN    -0.4790
# 32                                                NaN     0.2320
# 33                                                NaN    -1.4900
# 34                                                NaN    -1.5900
# 35                                                NaN    -4.8800
# 36                                                NaN    -0.5280
# 37                                                NaN    -1.0600
# 38                                                NaN        NaN
# 39                                                NaN        NaN
# 40                                                NaN        NaN
# 41                                                NaN    -4.3700
# 42                                                NaN     0.0720
# 43                                                NaN    -1.6500
# 44                                                NaN    -0.0196
# 45                                                NaN        NaN
# 46                                                NaN    -0.6520
# 47                                                NaN        NaN
# 48                                                NaN     0.9640
# 49                                                NaN    -0.3480
# 50                                                NaN     0.1740
# 51                                                NaN        NaN
# 52                                                NaN        NaN
# 53                                                NaN     0.1740
#
#                                     regulatoryRegions inLowComplexityRegion
# 0                                                 NaN                   NaN
# 1                                                 NaN                   NaN
# 2                                                 NaN                   NaN
# 3                                                 NaN                   NaN
# 4                                                 NaN                   NaN
# 5                                                 NaN                   NaN
# 6                                                 NaN                   NaN
# 7                                                 NaN                   NaN
# 8                                                 NaN                   NaN
# 9                                                 NaN                   NaN
# 10                                                NaN                   NaN
# 11                                                NaN                   NaN
# 12                                                NaN                   NaN
# 13                                                NaN                   NaN
# 14                                                NaN                   NaN
# 15                                                NaN                   NaN
# 16                                                NaN                   NaN
# 17                                                NaN                   NaN
# 18                                                NaN                   NaN
# 19                                                NaN                   NaN
# 20                                                NaN                   NaN
# 21                                                NaN                   NaN
# 22                                                NaN                   NaN
# 23                                                NaN                   NaN
# 24                                                NaN                   NaN
# 25  [{'id': 'ENSR00000222749', 'type': 'promoter_f...                   NaN
# 26                                                NaN                   NaN
# 27                                                NaN                   NaN
# 28                                                NaN                   NaN
# 29                                                NaN                   NaN
# 30                                                NaN                   NaN
# 31                                                NaN                   NaN
# 32                                                NaN                   NaN
# 33                                                NaN                   NaN
# 34                                                NaN                   NaN
# 35                                                NaN                   NaN
# 36                                                NaN                   NaN
# 37                                                NaN                  True
# 38                                                NaN                  True
# 39                                                NaN                  True
# 40                                                NaN                   NaN
# 41                                                NaN                   NaN
# 42                                                NaN                   NaN
# 43                                                NaN                   NaN
# 44                                                NaN                   NaN
# 45                                                NaN                   NaN
# 46                                                NaN                   NaN
# 47                                                NaN                   NaN
# 48                                                NaN                   NaN
# 49  [{'id': 'ENSR00000330098', 'type': 'CTCF_bindi...                   NaN
# 50  [{'id': 'ENSR00000330098', 'type': 'CTCF_bindi...                   NaN
# 51  [{'id': 'ENSR00000330098', 'type': 'CTCF_bindi...                   NaN
# 52  [{'id': 'ENSR00000330099', 'type': 'CTCF_bindi...                   NaN
# 53                                                NaN                   NaN
#
# [54 rows x 26 columns]

# %%
final_df.to_csv("/home/marc/example.tsv", sep="\t", index = False)

# %%
for i in range(0,5):
    print(final_df['regulatoryRegions'].dropna().iloc[i])
# Out:
# [{'id': 'ENSR00000222749', 'type': 'promoter_flanking_region', 'consequence': ['regulatory_region_variant']}]
# [{'id': 'ENSR00000330098', 'type': 'CTCF_binding_site', 'consequence': ['regulatory_region_variant']}]
# [{'id': 'ENSR00000330098', 'type': 'CTCF_binding_site', 'consequence': ['regulatory_region_variant']}]
# [{'id': 'ENSR00000330098', 'type': 'CTCF_binding_site', 'consequence': ['regulatory_region_variant']}]
# [{'id': 'ENSR00000330099', 'type': 'CTCF_binding_site', 'consequence': ['regulatory_region_variant']}]

# %%
for i in range(len(final_df["transcripts"])):
    print(f'Variant {final_df["vid"].iloc[i]} has {len(final_df["transcripts"].iloc[i])} affected transcripts')
# Out:
# Variant 8-161062-C-T has 1 affected transcripts
# Variant 8-161167-C-T has 2 affected transcripts
# Variant 8-161176-T-C has 2 affected transcripts
# Variant 8-161240-A-G has 2 affected transcripts
# Variant 8-163226-T-C has 2 affected transcripts
# Variant 8-163249-T-C has 2 affected transcripts
# Variant 8-163366-T-C has 2 affected transcripts
# Variant 8-163370-C-G has 2 affected transcripts
# Variant 8-163387-C-T has 2 affected transcripts
# Variant 8-163432-A-G has 2 affected transcripts
# Variant 8-163438-C-T has 2 affected transcripts
# Variant 8-163550-A-G has 2 affected transcripts
# Variant 8-163553-T-C has 2 affected transcripts
# Variant 8-163654-C-T has 2 affected transcripts
# Variant 8-163784-C-G has 2 affected transcripts
# Variant 8-169283-T-G has 2 affected transcripts
# Variant 8-169305-G-C has 2 affected transcripts
# Variant 8-169366-T-C has 2 affected transcripts
# Variant 8-169403-G-A has 2 affected transcripts
# Variant 8-169422-G-C has 2 affected transcripts
# Variant 8-169428-A-C has 2 affected transcripts
# Variant 8-169476-C-G has 2 affected transcripts
# Variant 8-169483-T-C has 2 affected transcripts
# Variant 8-169489-T-C has 2 affected transcripts
# Variant 8-169641-A-G has 2 affected transcripts
# Variant 8-28347508-A-G has 11 affected transcripts
# Variant 8-28357666-C-T has 11 affected transcripts
# Variant 8-28384712-A-G has 9 affected transcripts
# Variant 8-28421076-G-A has 3 affected transcripts
# Variant 8-28421781-A-C has 2 affected transcripts
# Variant 8-17867185-A-T has 13 affected transcripts
# Variant 8-17868029-C-A has 13 affected transcripts
# Variant 8-17868088-T-G has 13 affected transcripts
# Variant 8-17868219-C-T has 13 affected transcripts
# Variant 8-17868245-C-A has 13 affected transcripts
# Variant 8-17868521-T-C has 13 affected transcripts
# Variant 8-17871598-T-A has 13 affected transcripts
# Variant 8-17882712-C-G has 14 affected transcripts
# Variant 8-17882814-C-T has 14 affected transcripts
# Variant 8-17883296-G-A has 14 affected transcripts
# Variant 8-17885119-A-G has 14 affected transcripts
# Variant 8-17885384-T-C has 14 affected transcripts
# Variant 8-17885406-C-G has 14 affected transcripts
# Variant 8-17885862-A-G has 14 affected transcripts
# Variant 8-17885907-A-C has 14 affected transcripts
# Variant 8-17886026-G-A has 14 affected transcripts
# Variant 8-17886345-T-C has 15 affected transcripts
# Variant 8-17887062-T-C has 15 affected transcripts
# Variant 8-17887414-G-A has 14 affected transcripts
# Variant 8-17913753-T-C has 1 affected transcripts
# Variant 8-17913813-G-A has 1 affected transcripts
# Variant 8-17913970-G-A has 1 affected transcripts
# Variant 8-17914919-A-T has 1 affected transcripts
# Variant 8-17915299-T-C has 1 affected transcripts

# %%
def process_transcripts(final_df):
    pass
# Out:
# Index(['chromosome', 'position', 'refAllele', 'altAlleles', 'quality',
#        'filters', 'fisherStrandBias', 'mappingQuality', 'cytogeneticBand',
#        'vid', 'chromosome', 'begin', 'end', 'refAllele', 'altAllele',
#        'variantType', 'hgvsg', 'phylopScore', 'dannScore', 'transcripts',
#        'dbsnp', 'gnomad', 'topmed', 'gerpScore', 'regulatoryRegions',
#        'inLowComplexityRegion'],
#       dtype='object')
